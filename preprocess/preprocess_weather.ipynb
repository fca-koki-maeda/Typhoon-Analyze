# %%
import pandas as pd

input_file = "../data/weather/weather_2025.csv"

# 先頭10行をそのまま表示
df = pd.read_csv(
    input_file,
    # header=None,
    encoding="cp932",
    # nrows=10
)

print(df)

print("\n列数 =", df.shape[1])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                          ダウンロードした時刻：2026/07/13 07:21:18
# NaN          福岡    福岡      福岡      福岡      福岡        福岡  佐賀    佐賀      佐賀      佐賀      佐賀        佐賀  長崎    長崎      長崎      長崎      長崎        長崎  大分    大分      大分      大分      大分        大分  熊本    熊本      熊本      熊本      熊本        熊本  鹿児島   鹿児島     鹿児島     鹿児島     鹿児島       鹿児島 宮崎    宮崎      宮崎      宮崎      宮崎        宮崎  那覇    那覇      那覇      那覇      那覇                                    那覇
# ...
